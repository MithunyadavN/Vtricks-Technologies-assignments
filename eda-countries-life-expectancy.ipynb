# %% [markdown]
# ![bkj](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQRuv-F-xR2YhB1zpaXayzll2rTEnUNkOZMjQ&usqp=CAU)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df=pd.read_csv('../input/countries-life-expectancy/Life expectancy.csv')

# %%
df.head(10)
# Out:
#       Entity  Year  Life expectancy
# 0  Australia  1802        34.049999
# 1  Australia  1803        34.049999
# 2  Australia  1804        34.049999
# 3  Australia  1805        34.049999
# 4  Australia  1806        34.049999
# 5  Australia  1807        34.049999
# 6  Australia  1808        34.049999
# 7  Australia  1809        34.049999
# 8  Australia  1810        34.049999
# 9  Australia  1811        34.049999

# %%
df.tail()
# Out:
#              Entity  Year  Life expectancy
# 3248  United States  2012        78.940002
# 3249  United States  2013        78.959999
# 3250  United States  2014        78.940002
# 3251  United States  2015        78.870003
# 3252  United States  2016        78.860001

# %%
df.describe()
# Out:
#               Year  Life expectancy
# count  3253.000000      3253.000000
# mean   1908.066093        48.680380
# std      62.613962        17.965669
# min    1800.000000         8.108836
# 25%    1854.000000        32.000000
# 50%    1908.000000        41.880001
# 75%    1962.000000        66.820000
# max    2016.000000        83.940002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3253 entries, 0 to 3252
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Entity           3253 non-null   object
#  1   Year             3253 non-null   int64
#  2   Life expectancy  3253 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.4+ KB

# %%
df.isnull()
# Out:
#       Entity   Year  Life expectancy
# 0      False  False            False
# 1      False  False            False
# 2      False  False            False
# 3      False  False            False
# 4      False  False            False
# ...      ...    ...              ...
# 3248   False  False            False
# 3249   False  False            False
# 3250   False  False            False
# 3251   False  False            False
# 3252   False  False            False
#
# [3253 rows x 3 columns]

# %%
sns.scatterplot(x='Year', y='Life expectancy', data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Life expectancy'>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
# get correlation matrix
corr = df.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
# Out:
# [None, None, None, None]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df[df.columns[:8]].corr(),annot=True,cmap='Blues')
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
sns.pairplot(df, hue="Life expectancy");
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
df.head(1)
# Out:
#       Entity  Year  Life expectancy
# 0  Australia  1802        34.049999

# %%
import plotly.express as px
fig = px.scatter_3d(df.iloc[:500], x='Year', y='Life expectancy',z='Life expectancy',
                    color='Year')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
sns.distplot(df['Year'], color = 'r', label = 'target distribution')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
sns.distplot(df['Life expectancy'], color = 'r', label = 'target distribution')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Life expectancy', ylabel='Density'>

# %%
import matplotlib as mpl
# %matplotlib inline

df.hist(figsize=(18,10))
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:400: MatplotlibDeprecationWarning:
#
#
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.

# %%
plt.hist(df["Life expectancy"], bins = 30)
# Out:
# (array([  1.,   0.,   0.,   5.,   7.,  22., 109., 130., 274., 299., 140.,
#         306., 270., 146., 113.,  87.,  72.,  60.,  66.,  77.,  77.,  74.,
#          86., 110., 168., 125., 139., 120., 104.,  66.]),
#  array([ 8.1088362 , 10.63654173, 13.16424725, 15.69195278, 18.21965831,
#         20.74736383, 23.27506936, 25.80277489, 28.33048041, 30.85818594,
#         33.38589147, 35.91359699, 38.44130252, 40.96900805, 43.49671357,
#         46.0244191 , 48.55212463, 51.07983015, 53.60753568, 56.13524121,
#         58.66294673, 61.19065226, 63.71835779, 66.24606331, 68.77376884,
#         71.30147437, 73.82917989, 76.35688542, 78.88459095, 81.41229647,
#         83.940002  ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df["Year"], bins = 30)
# Out:
# (array([118., 105., 105., 105., 105., 120., 105., 105., 105., 105., 120.,
#         105., 105., 105., 105., 120., 105., 105., 105., 105., 120., 105.,
#         105., 105., 105., 120., 105., 105., 105., 120.]),
#  array([1800. , 1807.2, 1814.4, 1821.6, 1828.8, 1836. , 1843.2, 1850.4,
#         1857.6, 1864.8, 1872. , 1879.2, 1886.4, 1893.6, 1900.8, 1908. ,
#         1915.2, 1922.4, 1929.6, 1936.8, 1944. , 1951.2, 1958.4, 1965.6,
#         1972.8, 1980. , 1987.2, 1994.4, 2001.6, 2008.8, 2016. ]),
#  <BarContainer object of 30 artists>)

# %%
from sklearn.cluster import KMeans
K_clusters = range(1,8)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = df[['Year']]
X_axis = df[['Life expectancy']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.show()
